# %% [markdown]
# <a href="https://colab.research.google.com/github/aamish007/23-CS-006-CS318-DL-Lab/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
vocab_size = 10000

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

print("Training samples:", len(x_train))
print("Test samples:", len(x_test))
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training samples: 25000
# Test samples: 25000

# %%
max_len = 200

x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_len, padding='post')

print("Shape:", x_train.shape)
# Out:
# Shape: (25000, 200)

# %%
model = Sequential([

    # convert words → vectors
    Embedding(input_dim=vocab_size, output_dim=64, input_length=max_len),

    # RNN layer
    SimpleRNN(64, activation='tanh'),

    # output layer
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 86ms/step - accuracy: 0.5143 - loss: 0.6921 - val_accuracy: 0.5414 - val_loss: 0.6824
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.5993 - loss: 0.6554 - val_accuracy: 0.5976 - val_loss: 0.6391
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.6402 - loss: 0.5965 - val_accuracy: 0.5834 - val_loss: 0.6620
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 91ms/step - accuracy: 0.6582 - loss: 0.5697 - val_accuracy: 0.5534 - val_loss: 0.6653
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.6750 - loss: 0.5157 - val_accuracy: 0.6002 - val_loss: 0.6773

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.5993 - loss: 0.6763
# Test Accuracy: 0.5992799997329712

# %%
sample_review = x_test[10]
print(sample_review)
prediction = model.predict(np.array([sample_review]))

if prediction[0][0] > 0.5:
    print("Positive review 😊")
else:
    print("Negative review 😞")
# Out:
# [   7  107  349    2 1496   11 5116   18  397 3767    7    4  107   84
#  6763   56   68  456 1402    2   39    4 1374    9   35  204    5   55
#  4412  212  193   23    4  326   45    6 1109    8 1738    2   15   29
#   199 1040    5 2684   11   14 1403  212 1528   10   10 2160    2    9
#     4  452   37    2    4  598  425    5   45 4394  138   59  214  467
#     4 2391    7 1738    2   19   41 2455 3028    5 6866 1489   90  180
#    18  101 1403    2 1514 5257    9    4  564  871  322   47 2586   27
#   274  326    5    9  150  112    2   17    6   87  162 2133   60 3256
#    23    4 7999  123    8   11    2   29  144   30 2961 1346    2  214
#     4  326    7    2 1496    8 3767  533    7  134    2 6229   10   10
#     7  265  285    5  233   70  593   54  564 4124    2 1625   27 1546
#     2   19    2 1008   18   89    4  114 3209    5   45 1139   32    4
#    96  143 3760  958    7  919    5 7611  367    4   96   17   73   17
# ...
